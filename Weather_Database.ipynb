# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
latitudes = np.random.uniform(low=-90.000, high=90.000, size=2000)
longitudes = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_long = zip(latitudes, longitudes)
lat_long

# %%
coordinates = list(lat_long)

# %%
from citipy import citipy

# %%
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 737

# %%
import requests

from config import weather_api_key

# %%
url = "https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid=" + weather_api_key

# %%
city_url = url +"&q" + "Zocca"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': 10.99, 'lat': 44.34},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 289.59,
#   'feels_like': 289.33,
#   'temp_min': 287.92,
#   'temp_max': 290.75,
#   'pressure': 1013,
#   'humidity': 78,
#   'sea_level': 1013,
#   'grnd_level': 929},
#  'visibility': 10000,
#  'wind': {'speed': 2.82, 'deg': 200, 'gust': 4.52},
#  'clouds': {'all': 92},
#  'dt': 1663117238,
#  'sys': {'type': 2,
#   'id': 2044440,
#   'country': 'IT',
#   'sunrise': 1663131220,
#   'sunset': 1663176599},
#  'timezone': 7200,
#  'id': 3163858,
#  'name': 'Zocca',
#  'cod': 200}

# %%
import time
from datetime import datetime

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

# for i in range(len(cities)):
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#     city_url = url + "&q=" + "i"

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
 
    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

    try:
        city_weather = requests.get(city_url).json()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":current_description,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass


print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yima
# Processing Record 2 of Set 1 | chara
# Processing Record 3 of Set 1 | embonas
# Processing Record 4 of Set 1 | cayenne
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | cherskiy
# Processing Record 10 of Set 1 | palmer
# Processing Record 11 of Set 1 | rio grande
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | saint-pierre
# Processing Record 15 of Set 1 | northam
# Processing Record 16 of Set 1 | yuli
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | richards bay
# Processing Record 21 of Set 1 | stephenville crossing
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | magadan
# Processing Record 25 of Set 1 | ginda
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | kashi
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | faanui
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | jingdezhen
# Processing Record 33 of Set 1 | tres passos
# Processing Record 34 of Set 1 | meulaboh
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | bandarbeyla
# Processing Record 37 of Set 1 | namibe
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | mirzapur
# Processing Record 42 of Set 1 | moree
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 45 of Set 1 | pisco
# Processing Record 46 of Set 1 | darnah
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | anadyr
# Processing Record 49 of Set 1 | minas
# Processing Record 50 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 2 | ondo
# Processing Record 2 of Set 2 | westport
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | chiredzi
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | mamallapuram
# Processing Record 7 of Set 2 | karratha
# Processing Record 8 of Set 2 | kota belud
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | coquimbo
# Processing Record 12 of Set 2 | colares
# Processing Record 13 of Set 2 | nome
# Processing Record 14 of Set 2 | cape coast
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | komagane
# Processing Record 17 of Set 2 | villa maria
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | clyde river
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | rocha
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | mundwa
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | tromso
# Processing Record 27 of Set 2 | pudozh
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | gat
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 32 of Set 2 | gazanjyk
# Processing Record 33 of Set 2 | lorengau
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | cockburn town
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | lavrentiya
# Processing Record 38 of Set 2 | grindavik
# Processing Record 39 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 2 | laiagam
# City not found. Skipping...
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | tongliao
# Processing Record 43 of Set 2 | puerto leguizamo
# Processing Record 44 of Set 2 | taraclia
# Processing Record 45 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 2 | natal
# Processing Record 49 of Set 2 | vanimo
# Processing Record 50 of Set 2 | fortuna
# Processing Record 1 of Set 3 | rongcheng
# Processing Record 2 of Set 3 | linxia
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | rawson
# Processing Record 6 of Set 3 | bethel
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | bathsheba
# Processing Record 9 of Set 3 | sulurpeta
# City not found. Skipping...
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | yarmouth
# Processing Record 12 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 3 | hauterive
# Processing Record 14 of Set 3 | kutulik
# Processing Record 15 of Set 3 | victor harbor
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | kapit
# Processing Record 18 of Set 3 | fare
# Processing Record 19 of Set 3 | bekovo
# Processing Record 20 of Set 3 | san cristobal
# Processing Record 21 of Set 3 | havre-saint-pierre
# Processing Record 22 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 3 | adrar
# Processing Record 25 of Set 3 | kavaratti
# Processing Record 26 of Set 3 | muravlenko
# Processing Record 27 of Set 3 | japura
# Processing Record 28 of Set 3 | ariano irpino
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 3 | harrisburg
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 35 of Set 3 | yatou
# Processing Record 36 of Set 3 | morros
# Processing Record 37 of Set 3 | bestobe
# Processing Record 38 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | san ramon
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | husavik
# Processing Record 43 of Set 3 | lompoc
# Processing Record 44 of Set 3 | belmonte
# Processing Record 45 of Set 3 | coihaique
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | barrow
# Processing Record 48 of Set 3 | datong
# Processing Record 49 of Set 3 | abilene
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | llodio
# Processing Record 2 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 4 | shimoda
# Processing Record 4 of Set 4 | khromtau
# Processing Record 5 of Set 4 | kyren
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | sao paulo de olivenca
# Processing Record 8 of Set 4 | brae
# Processing Record 9 of Set 4 | khatanga
# Processing Record 10 of Set 4 | am timan
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | port hardy
# Processing Record 13 of Set 4 | casablanca
# Processing Record 14 of Set 4 | numaligarh
# Processing Record 15 of Set 4 | soe
# Processing Record 16 of Set 4 | paraiso
# Processing Record 17 of Set 4 | komsomolskiy
# Processing Record 18 of Set 4 | iralaya
# Processing Record 19 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 4 | veraval
# Processing Record 21 of Set 4 | ahipara
# Processing Record 22 of Set 4 | cabo san lucas
# Processing Record 23 of Set 4 | bredasdorp
# Processing Record 24 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 4 | lima
# Processing Record 28 of Set 4 | vietri sul mare
# Processing Record 29 of Set 4 | troitskoye
# Processing Record 30 of Set 4 | khed brahma
# Processing Record 31 of Set 4 | airai
# Processing Record 32 of Set 4 | port blair
# Processing Record 33 of Set 4 | axim
# Processing Record 34 of Set 4 | zastron
# Processing Record 35 of Set 4 | college
# Processing Record 36 of Set 4 | tekeli
# Processing Record 37 of Set 4 | ciudad bolivar
# Processing Record 38 of Set 4 | tautira
# Processing Record 39 of Set 4 | asau
# Processing Record 40 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 4 | soyaux
# Processing Record 42 of Set 4 | mehamn
# Processing Record 43 of Set 4 | faya
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | berlevag
# Processing Record 47 of Set 4 | tuktoyaktuk
# Processing Record 48 of Set 4 | samarai
# Processing Record 49 of Set 4 | bayan
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | vostok
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | talnakh
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | scarborough
# Processing Record 6 of Set 5 | cururupu
# Processing Record 7 of Set 5 | lodja
# Processing Record 8 of Set 5 | okoneshnikovo
# Processing Record 9 of Set 5 | tura
# Processing Record 10 of Set 5 | castro
# Processing Record 11 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | bandar-e lengeh
# Processing Record 14 of Set 5 | orodara
# Processing Record 15 of Set 5 | la palma
# Processing Record 16 of Set 5 | torbay
# Processing Record 17 of Set 5 | zhangjiakou
# Processing Record 18 of Set 5 | plastun
# Processing Record 19 of Set 5 | boguchany
# Processing Record 20 of Set 5 | ola
# Processing Record 21 of Set 5 | te anau
# Processing Record 22 of Set 5 | itaituba
# Processing Record 23 of Set 5 | cabinda
# Processing Record 24 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 5 | pokhara
# Processing Record 26 of Set 5 | springbok
# Processing Record 27 of Set 5 | mus
# Processing Record 28 of Set 5 | saint-philippe
# Processing Record 29 of Set 5 | el prat de llobregat
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | slyudyanka
# Processing Record 32 of Set 5 | noumea
# Processing Record 33 of Set 5 | krasnoye-na-volge
# Processing Record 34 of Set 5 | altay
# Processing Record 35 of Set 5 | leningradskiy
# Processing Record 36 of Set 5 | lagoa
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | muroto
# Processing Record 39 of Set 5 | pacific grove
# Processing Record 40 of Set 5 | nyurba
# Processing Record 41 of Set 5 | abha
# Processing Record 42 of Set 5 | bonthe
# Processing Record 43 of Set 5 | xuddur
# Processing Record 44 of Set 5 | nautla
# Processing Record 45 of Set 5 | acuna
# City not found. Skipping...
# Processing Record 46 of Set 5 | prince rupert
# Processing Record 47 of Set 5 | ballina
# Processing Record 48 of Set 5 | luderitz
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | forio
# Processing Record 1 of Set 6 | craig
# Processing Record 2 of Set 6 | bhinmal
# Processing Record 3 of Set 6 | esperance
# Processing Record 4 of Set 6 | buraydah
# Processing Record 5 of Set 6 | lepe
# Processing Record 6 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 6 | west lafayette
# Processing Record 8 of Set 6 | pangnirtung
# Processing Record 9 of Set 6 | linares
# Processing Record 10 of Set 6 | mattru
# Processing Record 11 of Set 6 | moa
# Processing Record 12 of Set 6 | fairbanks
# Processing Record 13 of Set 6 | mount gambier
# Processing Record 14 of Set 6 | schertz
# Processing Record 15 of Set 6 | mocajuba
# Processing Record 16 of Set 6 | hokitika
# Processing Record 17 of Set 6 | bayangol
# Processing Record 18 of Set 6 | tamiahua
# Processing Record 19 of Set 6 | butaritari
# Processing Record 20 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 6 | hilo
# Processing Record 22 of Set 6 | ambilobe
# Processing Record 23 of Set 6 | kruisfontein
# Processing Record 24 of Set 6 | nouakchott
# Processing Record 25 of Set 6 | araouane
# Processing Record 26 of Set 6 | ankpa
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | urucara
# Processing Record 29 of Set 6 | chifeng
# Processing Record 30 of Set 6 | singarayakonda
# Processing Record 31 of Set 6 | viedma
# Processing Record 32 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 33 of Set 6 | jacareacanga
# Processing Record 34 of Set 6 | tantoyuca
# Processing Record 35 of Set 6 | ponta delgada
# Processing Record 36 of Set 6 | puerto carreno
# Processing Record 37 of Set 6 | udachnyy
# Processing Record 38 of Set 6 | sistranda
# Processing Record 39 of Set 6 | guadalupe y calvo
# Processing Record 40 of Set 6 | batesville
# Processing Record 41 of Set 6 | sibu
# Processing Record 42 of Set 6 | kaeo
# Processing Record 43 of Set 6 | sao filipe
# Processing Record 44 of Set 6 | ruwi
# Processing Record 45 of Set 6 | carbondale
# Processing Record 46 of Set 6 | castrillon
# Processing Record 47 of Set 6 | manta
# Processing Record 48 of Set 6 | teahupoo
# Processing Record 49 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 50 of Set 6 | graaff-reinet
# Processing Record 1 of Set 7 | calabar
# Processing Record 2 of Set 7 | salinopolis
# Processing Record 3 of Set 7 | champerico
# Processing Record 4 of Set 7 | marsabit
# Processing Record 5 of Set 7 | pangai
# Processing Record 6 of Set 7 | yulara
# Processing Record 7 of Set 7 | bima
# Processing Record 8 of Set 7 | buala
# Processing Record 9 of Set 7 | dunedin
# Processing Record 10 of Set 7 | alofi
# Processing Record 11 of Set 7 | casma
# Processing Record 12 of Set 7 | waipawa
# Processing Record 13 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | dukat
# Processing Record 16 of Set 7 | chapais
# Processing Record 17 of Set 7 | riyadh
# Processing Record 18 of Set 7 | tilichiki
# Processing Record 19 of Set 7 | pacocha
# Processing Record 20 of Set 7 | san jeronimo
# Processing Record 21 of Set 7 | dipkarpaz
# City not found. Skipping...
# Processing Record 22 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 7 | manono
# Processing Record 24 of Set 7 | takanabe
# Processing Record 25 of Set 7 | hithadhoo
# Processing Record 26 of Set 7 | grand gaube
# Processing Record 27 of Set 7 | roma
# Processing Record 28 of Set 7 | hamadan
# Processing Record 29 of Set 7 | abnub
# Processing Record 30 of Set 7 | manadhoo
# Processing Record 31 of Set 7 | tyukhtet
# Processing Record 32 of Set 7 | bayshore gardens
# Processing Record 33 of Set 7 | vao
# Processing Record 34 of Set 7 | mormugao
# Processing Record 35 of Set 7 | kharp
# Processing Record 36 of Set 7 | kutum
# Processing Record 37 of Set 7 | parana
# Processing Record 38 of Set 7 | bethanien
# Processing Record 39 of Set 7 | male
# Processing Record 40 of Set 7 | santarem
# Processing Record 41 of Set 7 | terrace bay
# Processing Record 42 of Set 7 | balaguer
# Processing Record 43 of Set 7 | preobrazheniye
# Processing Record 44 of Set 7 | tezu
# Processing Record 45 of Set 7 | camacha
# Processing Record 46 of Set 7 | vila
# Processing Record 47 of Set 7 | katangli
# Processing Record 48 of Set 7 | banjar
# Processing Record 49 of Set 7 | nusaybin
# Processing Record 50 of Set 7 | maniitsoq
# Processing Record 1 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | margate
# Processing Record 4 of Set 8 | yerbogachen
# Processing Record 5 of Set 8 | bristol
# Processing Record 6 of Set 8 | jinchang
# Processing Record 7 of Set 8 | crailsheim
# Processing Record 8 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 8 | birjand
# Processing Record 10 of Set 8 | port hedland
# Processing Record 11 of Set 8 | vrangel
# Processing Record 12 of Set 8 | kuito
# Processing Record 13 of Set 8 | isangel
# Processing Record 14 of Set 8 | beachwood
# Processing Record 15 of Set 8 | hami
# Processing Record 16 of Set 8 | mezen
# Processing Record 17 of Set 8 | olavarria
# Processing Record 18 of Set 8 | qasigiannguit
# Processing Record 19 of Set 8 | victoria
# Processing Record 20 of Set 8 | kungurtug
# Processing Record 21 of Set 8 | ginir
# Processing Record 22 of Set 8 | dandong
# Processing Record 23 of Set 8 | goma
# Processing Record 24 of Set 8 | maralal
# Processing Record 25 of Set 8 | yaan
# Processing Record 26 of Set 8 | barahona
# Processing Record 27 of Set 8 | klaksvik
# Processing Record 28 of Set 8 | narasannapeta
# Processing Record 29 of Set 8 | icatu
# Processing Record 30 of Set 8 | laguna
# Processing Record 31 of Set 8 | hovd
# Processing Record 32 of Set 8 | port macquarie
# Processing Record 33 of Set 8 | praia da vitoria
# Processing Record 34 of Set 8 | nyrob
# Processing Record 35 of Set 8 | high prairie
# Processing Record 36 of Set 8 | malanje
# Processing Record 37 of Set 8 | hambantota
# Processing Record 38 of Set 8 | tignere
# Processing Record 39 of Set 8 | santa luzia
# Processing Record 40 of Set 8 | rio gallegos
# Processing Record 41 of Set 8 | naze
# Processing Record 42 of Set 8 | amapa
# Processing Record 43 of Set 8 | broken hill
# Processing Record 44 of Set 8 | nouadhibou
# Processing Record 45 of Set 8 | vestmannaeyjar
# Processing Record 46 of Set 8 | muli
# Processing Record 47 of Set 8 | lysyye gory
# Processing Record 48 of Set 8 | kirakira
# Processing Record 49 of Set 8 | sitka
# Processing Record 50 of Set 8 | zaraza
# Processing Record 1 of Set 9 | pinawa
# Processing Record 2 of Set 9 | pontian kecil
# Processing Record 3 of Set 9 | biloela
# Processing Record 4 of Set 9 | timizart
# Processing Record 5 of Set 9 | saint-francois
# Processing Record 6 of Set 9 | caravelas
# Processing Record 7 of Set 9 | medea
# Processing Record 8 of Set 9 | pak phanang
# Processing Record 9 of Set 9 | makubetsu
# Processing Record 10 of Set 9 | mutsu
# Processing Record 11 of Set 9 | bousso
# Processing Record 12 of Set 9 | asekeyevo
# Processing Record 13 of Set 9 | soyo
# Processing Record 14 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 9 | tokonou
# Processing Record 16 of Set 9 | russell
# Processing Record 17 of Set 9 | kloulklubed
# Processing Record 18 of Set 9 | zaranj
# Processing Record 19 of Set 9 | tranas
# Processing Record 20 of Set 9 | lahij
# Processing Record 21 of Set 9 | tarrafal
# Processing Record 22 of Set 9 | umm lajj
# Processing Record 23 of Set 9 | biltine
# Processing Record 24 of Set 9 | freeport
# Processing Record 25 of Set 9 | paredon
# Processing Record 26 of Set 9 | harper
# Processing Record 27 of Set 9 | shestakovo
# Processing Record 28 of Set 9 | taoudenni
# Processing Record 29 of Set 9 | yomou
# Processing Record 30 of Set 9 | abu dhabi
# Processing Record 31 of Set 9 | bambous virieux
# Processing Record 32 of Set 9 | balaipungut
# Processing Record 33 of Set 9 | villarrica
# Processing Record 34 of Set 9 | puerto madryn
# Processing Record 35 of Set 9 | omboue
# Processing Record 36 of Set 9 | lasa
# Processing Record 37 of Set 9 | sao joao da barra
# Processing Record 38 of Set 9 | khilok
# Processing Record 39 of Set 9 | peniche
# Processing Record 40 of Set 9 | maningrida
# Processing Record 41 of Set 9 | parnamirim
# Processing Record 42 of Set 9 | narsaq
# Processing Record 43 of Set 9 | sucre
# Processing Record 44 of Set 9 | candido mendes
# Processing Record 45 of Set 9 | bolgatanga
# Processing Record 46 of Set 9 | findlay
# Processing Record 47 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 9 | kelebia
# Processing Record 49 of Set 9 | beloha
# Processing Record 50 of Set 9 | beringovskiy
# Processing Record 1 of Set 10 | mawlaik
# Processing Record 2 of Set 10 | oropesa
# Processing Record 3 of Set 10 | bowen
# Processing Record 4 of Set 10 | loukhi
# Processing Record 5 of Set 10 | ngorongoro
# Processing Record 6 of Set 10 | provideniya
# Processing Record 7 of Set 10 | cabra
# Processing Record 8 of Set 10 | ambon
# Processing Record 9 of Set 10 | sayhat
# Processing Record 10 of Set 10 | smithers
# Processing Record 11 of Set 10 | awbari
# Processing Record 12 of Set 10 | kerki
# City not found. Skipping...
# Processing Record 13 of Set 10 | butterworth
# Processing Record 14 of Set 10 | avera
# Processing Record 15 of Set 10 | luba
# Processing Record 16 of Set 10 | bubaque
# Processing Record 17 of Set 10 | sinazongwe
# Processing Record 18 of Set 10 | shebalino
# Processing Record 19 of Set 10 | smithfield
# Processing Record 20 of Set 10 | tazovskiy
# Processing Record 21 of Set 10 | mantua
# Processing Record 22 of Set 10 | san jose
# Processing Record 23 of Set 10 | sinnamary
# Processing Record 24 of Set 10 | tuatapere
# Processing Record 25 of Set 10 | nuuk
# Processing Record 26 of Set 10 | paamiut
# Processing Record 27 of Set 10 | tynne
# Processing Record 28 of Set 10 | srednekolymsk
# Processing Record 29 of Set 10 | murray bridge
# Processing Record 30 of Set 10 | ancud
# Processing Record 31 of Set 10 | olkhovka
# Processing Record 32 of Set 10 | trinidad
# Processing Record 33 of Set 10 | inhambane
# Processing Record 34 of Set 10 | longonjo
# Processing Record 35 of Set 10 | ossora
# Processing Record 36 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 37 of Set 10 | plouzane
# Processing Record 38 of Set 10 | portland
# Processing Record 39 of Set 10 | sayyan
# Processing Record 40 of Set 10 | wladyslawowo
# Processing Record 41 of Set 10 | bermejo
# Processing Record 42 of Set 10 | aripuana
# Processing Record 43 of Set 10 | aykhal
# Processing Record 44 of Set 10 | bartica
# Processing Record 45 of Set 10 | cascais
# Processing Record 46 of Set 10 | oyon
# Processing Record 47 of Set 10 | sioux lookout
# Processing Record 48 of Set 10 | zemio
# Processing Record 49 of Set 10 | baraki barak
# Processing Record 50 of Set 10 | kpalime
# Processing Record 1 of Set 11 | teknaf
# Processing Record 2 of Set 11 | san vicente
# Processing Record 3 of Set 11 | divnomorskoye
# Processing Record 4 of Set 11 | borogontsy
# Processing Record 5 of Set 11 | lipari
# Processing Record 6 of Set 11 | general roca
# Processing Record 7 of Set 11 | gilbues
# Processing Record 8 of Set 11 | thunder bay
# Processing Record 9 of Set 11 | toamasina
# Processing Record 10 of Set 11 | sakyla
# Processing Record 11 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 11 | souillac
# Processing Record 13 of Set 11 | ilulissat
# Processing Record 14 of Set 11 | kavieng
# Processing Record 15 of Set 11 | seymchan
# Processing Record 16 of Set 11 | yar-sale
# Processing Record 17 of Set 11 | tanda
# Processing Record 18 of Set 11 | san gabriel casa blanca
# Processing Record 19 of Set 11 | bambanglipuro
# Processing Record 20 of Set 11 | ixtapa
# Processing Record 21 of Set 11 | jardim
# Processing Record 22 of Set 11 | hailar
# Processing Record 23 of Set 11 | buin
# Processing Record 24 of Set 11 | salto de pirapora
# Processing Record 25 of Set 11 | liseleje
# Processing Record 26 of Set 11 | sur
# Processing Record 27 of Set 11 | san patricio
# Processing Record 28 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 29 of Set 11 | torit
# Processing Record 30 of Set 11 | aiken
# Processing Record 31 of Set 11 | palu
# Processing Record 32 of Set 11 | baruun-urt
# Processing Record 33 of Set 11 | basseterre
# Processing Record 34 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 35 of Set 11 | sibolga
# Processing Record 36 of Set 11 | makakilo city
# Processing Record 37 of Set 11 | pakhtakoron
# Processing Record 38 of Set 11 | bud
# Processing Record 39 of Set 11 | los llanos de aridane
# Processing Record 40 of Set 11 | arcata
# Processing Record 41 of Set 11 | mwene-ditu
# Processing Record 42 of Set 11 | punta
# Processing Record 43 of Set 11 | khuzdar
# Processing Record 44 of Set 11 | najran
# Processing Record 45 of Set 11 | mount isa
# Processing Record 46 of Set 11 | lhokseumawe
# Processing Record 47 of Set 11 | pishin
# Processing Record 48 of Set 11 | darhan
# Processing Record 49 of Set 11 | hobyo
# Processing Record 50 of Set 11 | mayo
# Processing Record 1 of Set 12 | birao
# Processing Record 2 of Set 12 | saint anthony
# Processing Record 3 of Set 12 | san felipe
# Processing Record 4 of Set 12 | lata
# Processing Record 5 of Set 12 | mountain home
# Processing Record 6 of Set 12 | acapulco
# Processing Record 7 of Set 12 | dera bugti
# Processing Record 8 of Set 12 | kedrovyy
# Processing Record 9 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 12 | payo
# Processing Record 11 of Set 12 | hongjiang
# Processing Record 12 of Set 12 | salalah
# Processing Record 13 of Set 12 | anahuac
# Processing Record 14 of Set 12 | turukhansk
# Processing Record 15 of Set 12 | gorontalo
# Processing Record 16 of Set 12 | beitbridge
# Processing Record 17 of Set 12 | arman
# Processing Record 18 of Set 12 | karia
# Processing Record 19 of Set 12 | papar
# Processing Record 20 of Set 12 | touros
# Processing Record 21 of Set 12 | kahului
# Processing Record 22 of Set 12 | courtenay
# Processing Record 23 of Set 12 | agadir
# Processing Record 24 of Set 12 | acari
# Processing Record 25 of Set 12 | mumford
# Processing Record 26 of Set 12 | kiruna
# Processing Record 27 of Set 12 | berdigestyakh
# Processing Record 28 of Set 12 | amot
# Processing Record 29 of Set 12 | lazaro cardenas
# Processing Record 30 of Set 12 | egra
# Processing Record 31 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 12 | dauphin
# Processing Record 33 of Set 12 | dafeng
# Processing Record 34 of Set 12 | arica
# Processing Record 35 of Set 12 | vila franca do campo
# Processing Record 36 of Set 12 | taltal
# Processing Record 37 of Set 12 | aitape
# Processing Record 38 of Set 12 | sobolevo
# Processing Record 39 of Set 12 | umm kaddadah
# Processing Record 40 of Set 12 | kalmunai
# Processing Record 41 of Set 12 | adolfo lopez mateos
# Processing Record 42 of Set 12 | corrente
# Processing Record 43 of Set 12 | terney
# Processing Record 44 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 12 | thilogne
# City not found. Skipping...
# Processing Record 46 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 12 | xingyi
# Processing Record 48 of Set 12 | chuguyevka
# Processing Record 49 of Set 12 | baykit
# Processing Record 50 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 1 of Set 13 | bilma
# Processing Record 2 of Set 13 | juneau
# Processing Record 3 of Set 13 | buzmeyin
# Processing Record 4 of Set 13 | pemberton
# Processing Record 5 of Set 13 | juegang
# Processing Record 6 of Set 13 | portree
# Processing Record 7 of Set 13 | hervey bay
# Processing Record 8 of Set 13 | caribou
# Processing Record 9 of Set 13 | groningen
# Processing Record 10 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 11 of Set 13 | mahibadhoo
# Processing Record 12 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 13 | biak
# Processing Record 14 of Set 13 | shelburne
# Processing Record 15 of Set 13 | iwanai
# Processing Record 16 of Set 13 | kigoma
# Processing Record 17 of Set 13 | tiarei
# Processing Record 18 of Set 13 | xinpu
# Processing Record 19 of Set 13 | kargasok
# Processing Record 20 of Set 13 | panguna
# Processing Record 21 of Set 13 | olga
# Processing Record 22 of Set 13 | olafsvik
# Processing Record 23 of Set 13 | ulaanbaatar
# Processing Record 24 of Set 13 | saint-joseph
# Processing Record 25 of Set 13 | candido de abreu
# Processing Record 26 of Set 13 | berga
# Processing Record 27 of Set 13 | menongue
# Processing Record 28 of Set 13 | hualmay
# Processing Record 29 of Set 13 | luanda
# Processing Record 30 of Set 13 | mayumba
# Processing Record 31 of Set 13 | west wendover
# Processing Record 32 of Set 13 | santa cruz
# Processing Record 33 of Set 13 | poum
# Processing Record 34 of Set 13 | rupert
# Processing Record 35 of Set 13 | lulea
# Processing Record 36 of Set 13 | east stroudsburg
# Processing Record 37 of Set 13 | neiafu
# Processing Record 38 of Set 13 | maraa
# Processing Record 39 of Set 13 | kaitong
# Processing Record 40 of Set 13 | tir pol
# City not found. Skipping...
# Processing Record 41 of Set 13 | sotouboua
# Processing Record 42 of Set 13 | conceicao do araguaia
# Processing Record 43 of Set 13 | taree
# Processing Record 44 of Set 13 | vaxjo
# Processing Record 45 of Set 13 | praya
# Processing Record 46 of Set 13 | nuristan
# Processing Record 47 of Set 13 | santa fe
# Processing Record 48 of Set 13 | stornoway
# Processing Record 49 of Set 13 | andenes
# Processing Record 50 of Set 13 | kanlagay
# Processing Record 1 of Set 14 | ouadda
# Processing Record 2 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 14 | kibre mengist
# Processing Record 4 of Set 14 | dongsheng
# Processing Record 5 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 14 | bose
# Processing Record 7 of Set 14 | lalsot
# Processing Record 8 of Set 14 | tabora
# Processing Record 9 of Set 14 | wukari
# Processing Record 10 of Set 14 | atar
# Processing Record 11 of Set 14 | kwekwe
# Processing Record 12 of Set 14 | sterling
# Processing Record 13 of Set 14 | puerto escondido
# Processing Record 14 of Set 14 | norilsk
# Processing Record 15 of Set 14 | nantong
# Processing Record 16 of Set 14 | polessk
# Processing Record 17 of Set 14 | marawi
# Processing Record 18 of Set 14 | aswan
# Processing Record 19 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 14 | mpika
# Processing Record 21 of Set 14 | whitehorse
# Processing Record 22 of Set 14 | were ilu
# Processing Record 23 of Set 14 | constitucion
# Processing Record 24 of Set 14 | rundu
# Processing Record 25 of Set 14 | lebanon
# Processing Record 26 of Set 14 | mabaruma
# Processing Record 27 of Set 14 | yumen
# Processing Record 28 of Set 14 | shwebo
# Processing Record 29 of Set 14 | panaba
# Processing Record 30 of Set 14 | obluche
# City not found. Skipping...
# Processing Record 31 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 14 | oussouye
# Processing Record 33 of Set 14 | batagay
# Processing Record 34 of Set 14 | tashtagol
# Processing Record 35 of Set 14 | kailua
# Processing Record 36 of Set 14 | santa marta
# Processing Record 37 of Set 14 | fort smith
# Processing Record 38 of Set 14 | gravelbourg
# Processing Record 39 of Set 14 | chazuta
# Processing Record 40 of Set 14 | sebinkarahisar
# Processing Record 41 of Set 14 | napanee
# Processing Record 42 of Set 14 | burica
# City not found. Skipping...
# Processing Record 43 of Set 14 | quatre cocos
# Processing Record 44 of Set 14 | morgan city
# Processing Record 45 of Set 14 | mchinji
# Processing Record 46 of Set 14 | hatillo
# Processing Record 47 of Set 14 | tomatlan
# Processing Record 48 of Set 14 | hamilton
# Processing Record 49 of Set 14 | tabory
# Processing Record 50 of Set 14 | zhigansk
# Processing Record 1 of Set 15 | north bend
# Processing Record 2 of Set 15 | san miguel
# Processing Record 3 of Set 15 | esmeraldas
# Processing Record 4 of Set 15 | willowmore
# Processing Record 5 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 6 of Set 15 | digras
# Processing Record 7 of Set 15 | mogadishu
# Processing Record 8 of Set 15 | nichinan
# Processing Record 9 of Set 15 | key west
# Processing Record 10 of Set 15 | kotka
# Processing Record 11 of Set 15 | sao felix do xingu
# Processing Record 12 of Set 15 | sorland
# Processing Record 13 of Set 15 | bourail
# Processing Record 14 of Set 15 | olinda
# Processing Record 15 of Set 15 | sergiyevsk
# Processing Record 16 of Set 15 | motril
# Processing Record 17 of Set 15 | okandja
# City not found. Skipping...
# Processing Record 18 of Set 15 | yenagoa
# Processing Record 19 of Set 15 | salmo
# Processing Record 20 of Set 15 | gondanglegi
# Processing Record 21 of Set 15 | lepaera
# Processing Record 22 of Set 15 | marienburg
# Processing Record 23 of Set 15 | saint-georges
# Processing Record 24 of Set 15 | terrace
# Processing Record 25 of Set 15 | mandiana
# Processing Record 26 of Set 15 | qui nhon
# Processing Record 27 of Set 15 | okhotsk
# Processing Record 28 of Set 15 | zaykovo
# Processing Record 29 of Set 15 | mapimi
# Processing Record 30 of Set 15 | codrington
# Processing Record 31 of Set 15 | deputatskiy
# Processing Record 32 of Set 15 | venustiano carranza
# Processing Record 33 of Set 15 | parrita
# Processing Record 34 of Set 15 | aksarka
# Processing Record 35 of Set 15 | buenaventura
# Processing Record 36 of Set 15 | pervomayskiy
# Processing Record 37 of Set 15 | karasjok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Yima      CN  34.7381  111.8839    295.00        61           0
# 1       Chara      RU  56.9064  118.2631    281.62        61          43
# 2     Embonas      GR  36.2269   27.8564    295.28        60           0
# 3     Cayenne      GF   4.9333  -52.3333    300.17        83           0
# 4      Atuona      PF  -9.8000 -139.0333    297.90        69           0
# 5    Bengkulu      ID  -3.8004  102.2655    297.54        85         100
# 6       Vaini      TO -21.2000 -175.2000    301.24        74          20
# 7    Cherskiy      RU  68.7500  161.3000    275.84        87         100
# 8      Palmer      US  42.1584  -72.3287    295.37        86          75
# 9  Rio Grande      BR -32.0350  -52.0986    287.01        89          99
#
#    Wind Speed Current Description                 Date
# 0        3.36           clear sky  2022-09-14 01:09:00
# 1        2.31    scattered clouds  2022-09-14 01:09:00
# 2        8.55           clear sky  2022-09-14 01:09:01
# 3        0.00           clear sky  2022-09-14 01:05:30
# 4        5.58           clear sky  2022-09-14 01:09:02
# 5        1.07     overcast clouds  2022-09-14 01:09:02
# 6        2.57          few clouds  2022-09-14 01:09:04
# 7        2.77     overcast clouds  2022-09-14 01:09:04
# 8        0.00       broken clouds  2022-09-14 01:09:05
# 9        5.75     overcast clouds  2022-09-14 01:09:05

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
